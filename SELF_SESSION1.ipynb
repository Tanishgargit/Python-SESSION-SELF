# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanishgargit/Python-SESSION-SELF/blob/main/SELF_SESSION1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
